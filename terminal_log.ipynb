# %%
cd ~/Documents/Projects 
git clone git@github.com:LuqmaanSahar/D400-Problem-Set-3.git
cd D400-Problem-Set-3  
git switch -c dev
code .  

touch exercises.ipynb terminal_log.ipynb pyproject.toml

# %%
conda create --name d400_ps3_env python=3.12
conda activate d400_ps3_env
conda install numpy matplotlib ipywidgets scipy pandas
conda install -c conda-forge ipykernel     
conda env export --from-history > environment.yml
